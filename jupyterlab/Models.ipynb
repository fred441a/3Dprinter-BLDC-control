# %% [markdown]
# ## Model for torque to pressure
#
# $ \tau = F \cdot r$
#
# $ F = \frac{\tau}{r}$
#
#
# $ p = \frac{\tau}{A\cdot r}$
#
# A = area of filament
# r = Radius of extuder gear
# $\tau$ = torque

# %% [markdown]
# ## pressure to flowrate
#
# ![image.png](attachment:fa6153f2-84eb-4643-b5ae-a12cd7e003e4.png)
#
# Hagen–Poiseuille equation
