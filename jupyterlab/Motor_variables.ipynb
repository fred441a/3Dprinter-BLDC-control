# %% [markdown]
# ## From Datasheet
#
# ![image.png](attachment:cdd4bfaa-287e-4723-a039-47c9ecdc2d39.png)
#
# Lets recalculate to some actually usefull units

# %%
peak_stall_t = 2.5*0.0980665
peak_stall_t
# Out:
# 0.24516625

# %%
stalled_A = 1.2
Kt = peak_stall_t/stalled_A
Kt
# Out:
# 0.20430520833333335
