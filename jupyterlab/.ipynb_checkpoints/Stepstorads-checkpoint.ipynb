# %%
import math
steps_pr_mm = 0.001243
extruder_gearing = 200/31
Dextruder = 17.4

# %%
rads_pr_step = (steps_pr_mm/Dextruder)*2*math.pi
rads_pr_step
# Out:
# 0.00044885053659909343

# %%
rads_pr_step_pregear = rads_pr_step*extruder_gearing
rads_pr_step_pregear
# Out:
# 0.002895809913542538
