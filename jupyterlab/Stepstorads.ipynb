# %%
import math
steps_pr_mm = 0.001243
extruder_gearing = 200/31
Dextruder = 17.4
Oextruder = Dextruder * math.pi

# %%
rads_pr_step = (steps_pr_mm/Oextruder)*2*math.pi
rads_pr_step
# Out:
# 0.00014287356321839083

# %%
rads_pr_step_pregear = rads_pr_step*extruder_gearing
rads_pr_step_pregear
# Out:
# 0.0009217649239896182

# %%
extrusion_vel = 4;
period = 320 *10**6;

rads_extrude = (extrusion_vel / Oextruder)*2*math.pi
rads_extrude
# Out:
# 0.45977011494252873

# %%
rads_extrude_motor = rads_extrude*extruder_gearing
rads_extrude_motor
# Out:
# 2.9662588060808304

# %%
rads_extrude_motor/(1/292.25)
# Out:
# 866.8891360771228
